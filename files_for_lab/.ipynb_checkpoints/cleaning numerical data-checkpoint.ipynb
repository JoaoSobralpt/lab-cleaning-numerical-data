# %% [markdown]
# # 1 Import the necessary libraries.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # 2 Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df

# %%
df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
display(df.shape)
df.head()
# Out:
# (9134, 24)
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [markdown]
# # 3 First look at its main features (head, shape, info). NOTE The target column is total_claim_amount

# %%
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
df.shape
# Out:
# (9134, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
#checking stats for TCA
df['Total Claim Amount'].describe()
# Out:
# count    9134.000000
# mean      434.088794
# std       290.500092
# min         0.099007
# 25%       272.258244
# 50%       383.945434
# 75%       547.514839
# max      2893.239678
# Name: Total Claim Amount, dtype: float64

# %%
#checking Nans for TCA
df['Total Claim Amount'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # 4 Rename the columns so they follow the PE8 (snake case) (lower_case_with_underscores)

# %%
#replacing uppercases with lower and spaces with _
df.rename(columns=lambda x: x.lower().replace(' ', '_'), inplace=True)

# %%
df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
#checking if all columns were changed
df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %% [markdown]
# # 5 Change effective to date column to datetime format.

# %%
df['effective_to_date'] = pd.to_datetime(df['effective_to_date'], format='%m/%d/%y')
df['effective_to_date']
# Out:
# 0      2011-02-24
# 1      2011-01-31
# 2      2011-02-19
# 3      2011-01-20
# 4      2011-02-03
#           ...
# 9129   2011-02-10
# 9130   2011-02-12
# 9131   2011-02-06
# 9132   2011-02-03
# 9133   2011-02-14
# Name: effective_to_date, Length: 9134, dtype: datetime64[ns]

# %% [markdown]
# # 6 Create a NEW dataframe using only the numerical data called numerical_df. Use this for the following questions.

# %%
#checking numerical data
df.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
#confirming if numerical columns are all there
numerical_df = df.select_dtypes(include=['number'])
numerical_df.dtypes
# Out:
# customer_lifetime_value          float64
# income                             int64
# monthly_premium_auto               int64
# months_since_last_claim            int64
# months_since_policy_inception      int64
# number_of_open_complaints          int64
# number_of_policies                 int64
# total_claim_amount               float64
# dtype: object

# %% [markdown]
# # 7 Define a function that differentiates between continuous and discrete variables. Hint: The number of unique values might be useful.
# # Store continuous data into a continuous_df variable and do the same for discrete_df

# %%
numerical_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
# Find the maximum values for what i assume to be the discrete variables
max_months_since_last_claim = numerical_df['months_since_last_claim'].max()
max_months_since_policy_inception = numerical_df['months_since_policy_inception'].max()
max_number_of_open_complaints = numerical_df['number_of_open_complaints'].max()
max_number_of_policies = numerical_df['number_of_policies'].max()

# Print the maximum values
print("Max Months Since Last Claim:", max_months_since_last_claim)
print("Max Months Since Policy Inception:", max_months_since_policy_inception)
print("Max Number of Open Complaints:", max_number_of_open_complaints)
print("Max Number of Policies:", max_number_of_policies)
# Out:
# Max Months Since Last Claim: 35
# Max Months Since Policy Inception: 99
# Max Number of Open Complaints: 5
# Max Number of Policies: 9

# %%
def categorize_variables(numerical_df):
    #creating empty dictionaries
    continuous_vars = []
    discrete_vars = []
    
    for column in numerical_df.columns:
        unique_values = numerical_df[column].nunique()
        if unique_values > 100:  # As seen before the max value of all of discrete variables is 99 so i put 100 here
            continuous_vars.append(column)
        else:
            discrete_vars.append(column)
    
    return continuous_vars, discrete_vars
continuous_vars, discrete_vars = categorize_variables(numerical_df)

# %%
continuous_df = numerical_df[continuous_vars]
continuous_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       total_claim_amount
# 0             384.811147
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4             138.130879
# ...                  ...
# 9129          198.234764
# 9130          379.200000
# ...

# %%
discrete_df = numerical_df[discrete_vars]
discrete_df
# Out:
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies
# 0                             0                   1
# 1                             0                   8
# 2                             0                   2
# ...

# %% [markdown]
# # 8 Plot a correlation matrix, comment what you see.

# %%
# Calculate the correlation matrix
correlation_matrix = numerical_df.corr()


# Create a heatmap using Seaborn
sns.heatmap(correlation_matrix, annot=True)

plt.show()

# %% [markdown]
# ### Comments:
# -monthly_premium_auto and customer_lifetime_value have a moderate positive correlation (0.4), indicating that customers who pay higher monthly premiums tend to have higher lifetime values.
#
# -total_claim_amount and customer_lifetime_value have a weaker but still moderate positive correlation (0.23), indicating that customers who file larger claims may have slightly higher lifetime values.
#
# -total_claim_amount and income have a moderate negative correlation (-0.36), suggesting that higher income customers tend to have smaller claims.
#
# -total_claim_amount and monthly_premium_auto show a strong positive correlation (0.63), suggesting that customers with higher premiums also have higher claim amounts.
#
# -Other correlations are close to zero (below 0.05 or above -0.05), indicating weak relationships between those variables.

# %% [markdown]
# # 9 Create a function to plot every discrete variable. Do the same with the continuous variables
# # (Be Careful, you may need to change the plot type to one better suited for continuous data!)

# %%
# function for barplot for discrete variables
def plot_discrete_variables(dataframe):
    discrete_vars = dataframe.columns
    
    for column in discrete_vars:
        plt.figure(figsize=(6, 4))
        dataframe[column].value_counts().plot(kind='bar', color='skyblue')
        plt.title(f'Distribution of {column}')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.show()
plot_discrete_variables(discrete_df)

# %%
def plot_continuous_variables(dataframe):
    continuous_vars = dataframe.columns
    
    for column in continuous_vars:
        dataframe[column].plot(kind='hist', bins=20)
        plt.title(f'Distribution of {column}')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.show()
        
plot_continuous_variables(continuous_df)

# %% [markdown]
# # 10 Comment what you can see in the plots.

# %% [markdown]
# The concentration of data points is notably higher on the left side, while the tail on the right extends farther.
# Both discrete and continuous variables  are left-skewed (negatively-skewed)
# This skewness suggests that the data is not evenly distributed.
# The left skewed continuous variables, including Total Claim Amount, Monthly Premium Auto, and Customer Lifetime Value,
# exhibit outliers on their lower ends, indicating unusually low values that deviate from the majority.

# %% [markdown]
# # 11 Look for outliers in the continuous variables. (HINT: There’s a good plot to do that!)

# %%
#The box plot is the appropriate plot to look for outliers, so i will use it.
def plot_continuous_variables_box(dataframe):
    continuous_vars = dataframe.columns
    
    for column in continuous_vars:
        plt.figure(figsize=(6, 4))
        plt.boxplot(dataframe[column])
        plt.title(f'Box Plot of {column}')
        plt.xlabel(column)
        plt.ylabel('Value')
        plt.show()

plot_continuous_variables_box(continuous_df)

# %% [markdown]
# # 12 Did you find outliers? Comment what you will do with them.
# # If you decide to remove them, do that now. Also, remove them from your main dataframe.

# %% [markdown]
# ### Yes, i identified outliers , particularly in the Total Claim Amount and Customer Lifetime Value variables.
# ### I will remove them

# %%
# Define values for outliers
total_claim_amount_outliers = 2300
customer_lifetime_outliers = 70000

# Remove outliers from the main dataframe
cleaned_df = numerical_df[
    (df['total_claim_amount'] <= total_claim_amount_outliers) &
    (df['customer_lifetime_value'] <= customer_lifetime_outliers)
]

cleaned_df.shape
# Out:
# (9124, 8)

# %% [markdown]
# ##### 10 rows were deleted

# %%
# Update the main dataframe to the cleaned dataframe
numerical_df = cleaned_df
numerical_df.shape
# Out:
# (9124, 8)

# %% [markdown]
# #  13 Check all columns for NaN values. Decide what (if anything) you will need to do with them, do that now.

# %%
numerical_df.isnull().sum()
# Out:
# customer_lifetime_value          0
# income                           0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# total_claim_amount               0
# dtype: int64

# %% [markdown]
# ##### There are no NaN values.

# %% [markdown]
# # 14 Save the numerical_df to csv as numerical.csv You will use this file again this week.

# %%
numerical_df.to_csv('numerical.csv', index=False)

# %%
numerical_df = pd.read_csv('numerical.csv')
numerical_df.shape
# Out:
# (9124, 8)

# %%
numerical_df.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %% [markdown]
# # Lab | Cleaning categorical data

# %% [markdown]
# # 1 Open the notebook created for Lab-cleaning-numerical-data.

# %%
df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# # 2 Find all of the categorical data. Save it in a categorical_df variable.

# %%
# Selecing columns with categorical data types
categorical_columns = df.select_dtypes(include=['object']).columns

# Creating a new dataframe containing only the categorical columns
categorical_df = df[categorical_columns]

# %% [markdown]
# # 3 Check for NaN values and decide what to do with them, do it now

# %%
categorical_df.isnull().sum()
# Out:
# customer            0
# state               0
# response            0
# coverage            0
# education           0
# employmentstatus    0
# gender              0
# location_code       0
# marital_status      0
# policy_type         0
# policy              0
# renew_offer_type    0
# sales_channel       0
# vehicle_class       0
# vehicle_size        0
# dtype: int64

# %% [markdown]
# # 4 Check all unique values of columns.

# %%
for column in categorical_df.columns:
    unique_values = categorical_df[column].unique()
    print(f"{column}: {unique_values}")
# Out:
# customer: ['BU79786' 'QZ44356' 'AI49188' ... 'TD14365' 'UP19263' 'Y167826']
# state: ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon']
# response: ['No' 'Yes']
# coverage: ['Basic' 'Extended' 'Premium']
# education: ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# employmentstatus: ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']
# gender: ['F' 'M']
# location_code: ['Suburban' 'Rural' 'Urban']
# marital_status: ['Married' 'Single' 'Divorced']
# policy_type: ['Corporate Auto' 'Personal Auto' 'Special Auto']
# policy: ['Corporate L3' 'Personal L3' 'Corporate L2' 'Personal L1' 'Special L2'
#  'Corporate L1' 'Personal L2' 'Special L1' 'Special L3']
# renew_offer_type: ['Offer1' 'Offer3' 'Offer2' 'Offer4']
# sales_channel: ['Agent' 'Call Center' 'Web' 'Branch']
# vehicle_class: ['Two-Door Car' 'Four-Door Car' 'SUV' 'Luxury SUV' 'Sports Car'
#  'Luxury Car']
# vehicle_size: ['Medsize' 'Small' 'Large']

# %% [markdown]
# # 5 Check dtypes. Do they all make sense as categorical data?

# %%
for column in categorical_df.columns:
    data_type = categorical_df[column].dtype
    print(f"{column}: {data_type}")
# Out:
# customer: object
# state: object
# response: object
# coverage: object
# education: object
# employmentstatus: object
# gender: object
# location_code: object
# marital_status: object
# policy_type: object
# policy: object
# renew_offer_type: object
# sales_channel: object
# vehicle_class: object
# vehicle_size: object

# %% [markdown]
# ##### I think customer doesn't make sense as categorical.

# %% [markdown]
# # 6 Does any column contain alpha and numeric data? Decide how to clean it and do it now.

# %% [markdown]
# ##### Yes, customer contains alphanumeric data, i think it won't be needed on the categorical data, but i don't want to delete the row, because i might need it later, so i will just drop that column from my categorical_df dataframe

# %%
categorical_df = categorical_df.drop(columns=['customer'])
categorical_df
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type        policy  \
# ...

# %% [markdown]
# # 7 Would you choose to do anything else to clean or wrangle the categorical data? Comment your decisions and do it now.

# %%
for column in categorical_df.columns:
    counts = categorical_df[column].value_counts()
    print(f" {column} : {counts}" )
# Out:
#  state : California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
#  response : No     7826
# Yes    1308
# Name: response, dtype: int64
#  coverage : Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
#  education : Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: education, dtype: int64
#  employmentstatus : Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64
#  gender : F    4658
# M    4476
# Name: gender, dtype: int64
#  location_code : Suburban    5779
# Rural       1773
# Urban       1582
# Name: location_code, dtype: int64
#  marital_status : Married     5298
# Single      2467
# Divorced    1369
# Name: marital_status, dtype: int64
# ...

# %% [markdown]
# ##### For now, no. The categorical data seems to be clean and well-structured. Each categorical variable has distinct categories that make sense for their respective contexts.

# %% [markdown]
# # 8 Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?

# %% [markdown]
# The columns policy_type and policy both seem to contain information related to the type of insurance policy held by the customers. However, they provide different levels of detail:
#
# Policy Type (policy_type): Appears to categorize policies into broader types such as "Personal Auto," "Corporate Auto," and "Special Auto." It seems to group policies based on some high-level categorization.
#
# Policy (policy): Provides more specific information about the policy types. It includes variations within each type, such as "Personal L1," "Personal L2," "Personal L3," "Corporate L1," "Corporate L2," and so on.
#
# In terms of importance for modeling, it would be more meaningful to focus on the policy_type column as it provides a high-level categorization of policy types.
#
# Given this info I will drop policy from my categorical

# %%
categorical_df = categorical_df.drop(columns=['policy'])
categorical_df
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type renew_offer_type  \
# ...

# %% [markdown]
# # 9 Check number of unique values in each column, can they be combined in any way to ease encoding? Comment your thoughts and make those changes.

# %%
for column in categorical_df.columns:
    counts = categorical_df[column].value_counts()
    print(f" {column} : {counts}" )
# Out:
#  state : California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
#  response : No     7826
# Yes    1308
# Name: response, dtype: int64
#  coverage : Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
#  education : Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: education, dtype: int64
#  employmentstatus : Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64
#  gender : F    4658
# M    4476
# Name: gender, dtype: int64
#  location_code : Suburban    5779
# Rural       1773
# Urban       1582
# Name: location_code, dtype: int64
#  marital_status : Married     5298
# Single      2467
# Divorced    1369
# Name: marital_status, dtype: int64
# ...

# %% [markdown]
# ### Yes they can, i can ease encoding by combining categories on education, employement status and vehicles.

# %%
education_mapping = {
    'Bachelor': 'Bachelor',
    'College': 'College',
    'High School or Below': 'High School or Below',
    'Master': 'Higher Degree',
    'Doctor': 'Higher Degree'
}

categorical_df['education'] = categorical_df['education'].replace(education_mapping)

# %%
employment_mapping = {
    'Employed': 'Employed',
    'Unemployed': 'Unemployed',
    'Medical Leave': 'Other',
    'Disabled': 'Other',
    'Retired': 'Other'
}

categorical_df['employmentstatus'] = categorical_df['employmentstatus'].replace(employment_mapping)

# %%
vehicle_class_mapping = {
    'Four-Door Car': 'Car',
    'Two-Door Car': 'Car',
    'SUV': 'SUV',
    'Sports Car': 'Car',
    'Luxury SUV': 'SUV',
    'Luxury Car': 'Car'
}

categorical_df['vehicle_class'] = categorical_df['vehicle_class'].replace(vehicle_class_mapping)

# %%
for column in categorical_df.columns:
    counts = categorical_df[column].value_counts()
    print(f" {column} : {counts}" )
# Out:
#  state : California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
#  response : No     7826
# Yes    1308
# Name: response, dtype: int64
#  coverage : Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
#  education : Bachelor                2748
# College                 2681
# High School or Below    2622
# Higher Degree           1083
# Name: education, dtype: int64
#  employmentstatus : Employed      5698
# Unemployed    2317
# Other         1119
# Name: employmentstatus, dtype: int64
#  gender : F    4658
# M    4476
# Name: gender, dtype: int64
#  location_code : Suburban    5779
# Rural       1773
# Urban       1582
# Name: location_code, dtype: int64
#  marital_status : Married     5298
# Single      2467
# Divorced    1369
# Name: marital_status, dtype: int64
#  policy_type : Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# ...

# %% [markdown]
# # 10 Save the cleaned catagorical dataframe as categorical.csv You will use this file again this week.

# %%
categorical_df.to_csv('categorical.csv', index=False)

# %% [markdown]
# # ------------------------------------------ END OF LAB-------------------------------------------

# %% [markdown]
# # 1 Open the categorical dataframe we created before.

# %%
categorical_df = pd.read_csv('categorical.csv')
categorical_df
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type renew_offer_type  \
# ...

# %% [markdown]
# # 2 Plot all the categorical variables with the proper plot. What can you see?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Loop through each categorical column and create bar plots, that is the indicated plot for categoricals
for column in categorical_df.columns:
    sns.countplot(data=categorical_df, x=column, order=categorical_df[column].value_counts().index)
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# # 3 There might be some columns that seem to be redundant, check their values to be sure. What should we do with them? Make any changes you feel are necessary.

# %%
for column in categorical_df.columns:
    value_counts = categorical_df[column].value_counts()
    print(f"{column}:\n{value_counts}\n")
# Out:
# state:
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
#
# response:
# No     7826
# Yes    1308
# Name: response, dtype: int64
#
# coverage:
# Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
#
# education:
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Higher Degree           1083
# Name: education, dtype: int64
#
# employmentstatus:
# Employed      5698
# Unemployed    2317
# Other         1119
# Name: employmentstatus, dtype: int64
#
# gender:
# F    4658
# M    4476
# Name: gender, dtype: int64
#
# location_code:
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: location_code, dtype: int64
#
# marital_status:
# Married     5298
# Single      2467
# Divorced    1369
# Name: marital_status, dtype: int64
#
# policy_type:
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# ...

# %% [markdown]
# ### I wasn't able to find any redundants values

# %% [markdown]
# # 4 Plot time variable. Can you extract something from it?

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['effective_to_date'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Effective Date')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 5 The time variable can be useful. You shoud transform its data into a more useful form. Hint: Day, week, and month as integers might be useful.

# %%
df['day'] = df['effective_to_date'].dt.day
df['week'] = df['effective_to_date'].dt.week
df['month'] = df['effective_to_date'].dt.month
# Out:
# C:\Users\jmcso\AppData\Local\Temp\ipykernel_4932\2126683386.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week'] = df['effective_to_date'].dt.week

# %% [markdown]
# # Lab | Comparing regression models

# %% [markdown]
# # 1 In this final lab, we will model our data. Import sklearn train_test_split and separate the data.

# %%
numerical_data = pd.read_csv('numerical.csv')
categorical_data = pd.read_csv('categorical.csv')

# %%
# Concatenate numerical and categorical dataframes
data = pd.concat([numerical_data, categorical_data], axis=1)

# %% [markdown]
# # 2 Separate X_train and X_test into numerical and categorical (X_train_cat , X_train_num , X_test_cat , X_test_num)

# %%
# Splitting into features (X) and target (y)
X = data.drop(columns=['total_claim_amount'])  # Features
y = data['total_claim_amount']  # Target

# %% [markdown]
# # 3 Use X_train_num to fit scalers. Transform BOTH X_train_num and X_test_num.

# %%
# Splitting into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1337)

# %%
# 4

# %%
# Separating numerical and categorical features
X_train_num = X_train.select_dtypes(include=['float64', 'int64'])
X_test_num = X_test.select_dtypes(include=['float64', 'int64'])

X_train_cat = X_train.select_dtypes(include=['object'])
X_test_cat = X_test.select_dtypes(include=['object'])

# %%
# Ordinal encoding 'coverage', 'employmentstatus', 'location code', 'vehicle size', and 'education'
ordinal_columns = ['coverage', 'employmentstatus', 'location_code', 'vehicle_size', 'education']
ordinal_encoder = OrdinalEncoder(categories='auto')  
X_train_cat_encoded = ordinal_encoder.fit_transform(X_train_cat[ordinal_columns])
X_test_cat_encoded = ordinal_encoder.transform(X_test_cat[ordinal_columns])

# %%
# Creating DataFrames for ordinal encoded categorical features
X_train_cat_encoded_df = pd.DataFrame(X_train_cat_encoded, columns=ordinal_columns)
X_test_cat_encoded_df = pd.DataFrame(X_test_cat_encoded, columns=ordinal_columns)

# %%
# One-hot encoding remaining categorical features
onehot_columns = ['state', 'marital_status', 'policy_type', 'renew_offer_type', 'sales_channel', 'vehicle_class', 'response', 'gender']
onehot_encoder = OneHotEncoder(handle_unknown='error', drop='first')
X_train_onehot_encoded = onehot_encoder.fit_transform(X_train_cat[onehot_columns])
X_test_onehot_encoded = onehot_encoder.transform(X_test_cat[onehot_columns])

X_train_onehot_encoded_df = pd.DataFrame(X_train_onehot_encoded.toarray(), columns=onehot_encoder.get_feature_names_out(input_features=onehot_columns))
X_test_onehot_encoded_df = pd.DataFrame(X_test_onehot_encoded.toarray(), columns=onehot_encoder.get_feature_names_out(input_features=onehot_columns))

# %%
# Concatenating scaled numerical, ordinal, and one-hot encoded categorical features
scaler = StandardScaler()
X_train_num_scaled = scaler.fit_transform(X_train_num)
X_test_num_scaled = scaler.transform(X_test_num)

X_train_treated = pd.concat([pd.DataFrame(X_train_num_scaled, columns=X_train_num.columns), X_train_cat_encoded_df, X_train_onehot_encoded_df], axis=1)
X_test_treated = pd.concat([pd.DataFrame(X_test_num_scaled, columns=X_test_num.columns), X_test_cat_encoded_df, X_test_onehot_encoded_df], axis=1)

# %% [markdown]
# # 5 Since the model will only accept numerical data, check and make sure that every column is numerical, if some are not, change it using encoding.

# %%
X_train_treated.isnull().sum()
# Out:
# customer_lifetime_value          5
# income                           5
# monthly_premium_auto             5
# months_since_last_claim          5
# months_since_policy_inception    5
# number_of_open_complaints        5
# number_of_policies               5
# dtype: int64

# %%
# Out:
# customer_lifetime_value          5
# income                           5
# monthly_premium_auto             5
# months_since_last_claim          5
# months_since_policy_inception    5
# number_of_open_complaints        5
# number_of_policies               5
# dtype: int64

# %%
 y_train.isnull().sum()
# Out:
# 5

# %% [markdown]
# # 6. Try a simple linear regression with all the data to see whether we are getting good results.

# %%
linear_reg_model = LinearRegression()
linear_reg_model.fit(X_train_imputed, y_train)
y_pred = linear_reg_model.predict(X_test_imputed)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 2
#       1 linear_reg_model = LinearRegression()
# ----> 2 linear_reg_model.fit(X_train_imputed, y_train)
#       3 y_pred = linear_reg_model.predict(X_test_imputed)
#       5 mse = mean_squared_error(y_test, y_pred)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
# ...

# %% [markdown]
# The value 0.5185 means that the regression model has 51.85% variance , so it doesnt seem that this Linear Regression Model is very good.

# %% [markdown]
# # 7. Now define a function that takes a list of models and train (and tests) them so we can try a lot of them without repeating code.

# %%
def train_and_evaluate_models(models, X_train, y_train, X_test, y_test):
    results = []
    
    for model in models:
        model_name = model.__class__.__name__
        
        # Training the model
        model.fit(X_train, y_train)
        
        # Making predictions on the test set
        y_pred = model.predict(X_test)
        
        # Calculating evaluation metrics
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)
        
        results.append({
            'model': model_name,
            'mse': mse,
            'r2': r2
        })
        
    return results

# %% [markdown]
# ### I will go back to comparing regression models lab in the weekend ("Not Finished, having errors with NaN values")

# %% [markdown]
# # Lab | Random variable distributions

# %% [markdown]
# # 1 Use the numerical variables from our dataset this week.

# %%
# Load the dataset
data = pd.read_csv('numerical.csv')
data
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9119             23405.987980   71941                    73
# 9120              3096.511217   21604                    79
# 9121              8163.890428       0                    85
# 9122              7524.442436   21941                    96
# 9123              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# # 2 Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
# Iterating for each numerical variable to do distribution plots
for col in data.columns:
    sns.displot(data[col],kde=True)
    plt.show()

# %% [markdown]
# ### From the visualization of the plots, we can confirm that not all variables have normal distribution, some have exponential distribution( are skewed to the right)

# %% [markdown]
# # 3 Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
numerical_transformed=np.where(np.isfinite(np.log10(data)),np.log10(data),0)
# Out:
# C:\Users\jmcso\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:351: RuntimeWarning: divide by zero encountered in log10
#   result = func(self.values, **kwargs)

# %%
#the result is an array so converting it to a datafranme for better readability and plotting

numerical_transformed=pd.DataFrame(numerical_transformed,columns=data.columns)
numerical_transformed
# Out:
#       customer_lifetime_value    income  monthly_premium_auto  \
# 0                    3.441462  4.750308              1.838849
# 1                    3.843827  0.000000              1.973128
# 2                    4.110166  4.688126              2.033424
# 3                    3.883426  0.000000              2.025306
# 4                    3.449277  4.641831              1.863323
# ...                       ...       ...                   ...
# 9119                 4.369327  4.856976              1.863323
# 9120                 3.490873  4.334534              1.897627
# 9121                 3.911897  0.000000              1.929419
# 9122                 3.876474  4.341256              1.982271
# 9123                 3.416946  0.000000              1.886491
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    1.505150                       0.698970
# 1                    1.113943                       1.623249
# ...

# %%
for col in num_transformed.columns:
    sns.displot(num_transformed[col],kde=True)
    plt.show()

# %%
# Square root transforming
numerical_sqrt=np.sqrt(data)
numerical_sqrt
# Out:
#       customer_lifetime_value      income  monthly_premium_auto  \
# 0                   52.569186  237.221416              8.306624
# 1                   83.543617    0.000000              9.695360
# 2                  113.522824  220.832516             10.392305
# 3                   87.440619    0.000000             10.295630
# 4                   53.044251  209.370485              8.544004
# ...                       ...         ...                   ...
# 9119               152.990156  268.218195              8.544004
# 9120                55.646305  146.982992              8.888194
# 9121                90.354250    0.000000              9.219544
# 9122                86.743544  148.124947              9.797959
# 9123                51.106133    0.000000              8.774964
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    5.656854                       2.236068
# 1                    3.605551                       6.480741
# ...

# %%
for col in num_sqrt.columns:
    sns.displot(num_sqrt[col],kde=True)
    plt.show()

# %%
#Cubic root transformation
numerical_cbrt=np.cbrt(data)
numerical_cbrt
# Out:
#       customer_lifetime_value     income  monthly_premium_auto  \
# 0                   14.033118  38.320920              4.101566
# 1                   19.110652   0.000000              4.546836
# 2                   23.445282  36.534964              4.762203
# 3                   19.700420   0.000000              4.732623
# 4                   14.117535  35.259567              4.179339
# ...                       ...        ...                   ...
# 9119                28.605025  41.590310              4.179339
# 9120                14.575525  27.851252              4.290840
# 9121                20.135653   0.000000              4.396830
# 9122                19.595579  27.995322              4.578857
# 9123                13.771524   0.000000              4.254321
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    3.174802                       1.709976
# 1                    2.351335                       3.476027
# ...

# %%
for col in numerical_cbrt.columns:
    sns.displot(numerical_cbrt[col],kde=True)
    plt.show()
